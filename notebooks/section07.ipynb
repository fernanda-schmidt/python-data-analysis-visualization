# %% [markdown]
# ## Section 07
# ### Indexing & Sorting
# * Vid 48: Set_Index Basics
# * Vid 49: set_index: The World Happiness Index Dataset
# * Vid 50: setting index with read.csv
# * Vid 51: sort_values intro
# * Vid 52: sorting by multiple columns
# * Vid 53: sorting text columns
# * Vid 54: sort_index
# * Vid 55: Sorting and Plotting
# * Vid 56: loc
# * Vid 57: iloc
# * Vid 58: loc & iloc with Series

# %% [markdown]
# ##### Vid 48

# %%
import pandas as pd
btc = pd.read_csv('../datasets/data/coin_Bitcoin.csv')

# %%
btc.set_index('Date')
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %% [markdown]
# ##### Vid 49

# %%
wh = pd.read_csv('../datasets/data/world-happiness-report-2021.csv')

# %%
wh['Healthy life expectancy']
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
wh.set_index('Country name', inplace=True)

# %%
wh
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
wh['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %% [markdown]
# ##### Vid 50

# %%
df = pd.read_csv('../datasets/data/world-happiness-report-2021.csv', index_col=0)
df
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
# ##### Vid 51

# %%
wh.sort_values('Healthy life expectancy')
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Chad                       Sub-Saharan Africa         4.355
# Lesotho                    Sub-Saharan Africa         3.512
# Nigeria                    Sub-Saharan Africa         4.759
# Ivory Coast                Sub-Saharan Africa         5.306
# Swaziland                  Sub-Saharan Africa         4.308
# ...                                       ...           ...
# Switzerland                    Western Europe         7.571
# Spain                          Western Europe         6.491
# Japan                               East Asia         5.940
# Hong Kong S.A.R. of China           East Asia         5.477
# Singapore                      Southeast Asia         6.377
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Chad                                                0.094         4.540
# ...

# %%
wh.sort_values('Healthy life expectancy', ascending=False)
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %% [markdown]
# ##### Vid 52

# %%
houses = pd.read_csv('../datasets/data/kc_house_data.csv')
titanic = pd.read_csv('../datasets/data/titanic.csv')

# %%
houses.sort_values('price', ascending=False).head(10)
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.sort_values(['bedrooms', 'price'], ascending=False).head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 19254         2920      3745     2.0           0     0  ...      7
# 15161         3610     11914     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
# ...

# %%
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
titanic.sort_values('name')
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
titanic.sort_values('name', key=lambda col: col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %% [markdown]
# ##### Vid 54

# %%
wh.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %% [markdown]
# ##### Vid 55

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='pclass'>

# %%
houses.bedrooms.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# ##### Vid 56

# %%
wh.loc['Yemen']
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         3.658
# Standard error of ladder score                                        0.07
# upperwhisker                                                         3.794
# lowerwhisker                                                         3.521
# Logged GDP per capita                                                7.578
# Social support                                                       0.832
# Healthy life expectancy                                             57.122
# Freedom to make life choices                                         0.602
# Generosity                                                          -0.147
# Perceptions of corruption                                              0.8
# Ladder score in Dystopia                                              2.43
# ...

# %%
wh.loc['Brazil']
# Out:
# Regional indicator                            Latin America and Caribbean
# Ladder score                                                         6.33
# Standard error of ladder score                                      0.043
# upperwhisker                                                        6.415
# lowerwhisker                                                        6.245
# Logged GDP per capita                                               9.577
# Social support                                                      0.882
# Healthy life expectancy                                            66.601
# Freedom to make life choices                                        0.804
# Generosity                                                         -0.071
# Perceptions of corruption                                           0.756
# Ladder score in Dystopia                                             2.43
# Explained by: Log GDP per capita                                    1.028
# ...

# %%
wh.loc[['Canada', 'Mexico','United States']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Canada               North America and ANZ         7.103
# Mexico         Latin America and Caribbean         6.317
# United States        North America and ANZ         6.951
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Canada                                  0.042         7.185         7.021
# Mexico                                  0.053         6.420         6.213
# United States                           0.049         7.047         6.856
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Canada                        10.776           0.926                   73.800
# Mexico                         9.859           0.831                   68.597
# United States                 11.023           0.920                   68.200
#
#                Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
titanic.loc[7]
# Out:
# pclass                            1
# survived                          0
# name         Andrews, Mr. Thomas Jr
# sex                            male
# age                              39
# sibsp                             0
# parch                             0
# ticket                       112050
# fare                              0
# cabin                           A36
# embarked                          S
# boat                              ?
# body                              ?
# home.dest               Belfast, NI
# Name: 7, dtype: object

# %%
titanic.loc[5:10]
# Out:
#     pclass  survived                                           name     sex  \
# 5        1         1                            Anderson, Mr. Harry    male
# 6        1         1              Andrews, Miss. Kornelia Theodosia  female
# 7        1         0                         Andrews, Mr. Thomas Jr    male
# 8        1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1         0                        Artagaveytia, Mr. Ramon    male
# 10       1         0                         Astor, Col. John Jacob    male
#
#    age  sibsp  parch    ticket     fare    cabin embarked boat body  \
# 5   48      0      0     19952    26.55      E12        S    3    ?
# 6   63      1      0     13502  77.9583       D7        S   10    ?
# 7   39      0      0    112050        0      A36        S    ?    ?
# 8   53      2      0     11769  51.4792     C101        S    D    ?
# 9   71      0      0  PC 17609  49.5042        ?        C    ?   22
# ...

# %%
wh.sort_index().loc['Denmark':'France']
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Denmark                           Western Europe         7.620
# Dominican Republic   Latin America and Caribbean         5.545
# Ecuador              Latin America and Caribbean         5.764
# Egypt               Middle East and North Africa         4.283
# El Salvador          Latin America and Caribbean         6.061
# Estonia               Central and Eastern Europe         6.189
# Ethiopia                      Sub-Saharan Africa         4.275
# Finland                           Western Europe         7.842
# France                            Western Europe         6.690
#
#                     Standard error of ladder score  upperwhisker  \
# Country name
# Denmark                                      0.035         7.687
# Dominican Republic                           0.071         5.685
# Ecuador                                      0.057         5.875
# ...

# %% [markdown]
# ##### Vid 57

# %%
wh.iloc[20]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
wh.iloc[[10,20,30]]
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Australia           North America and ANZ         7.183
# France                     Western Europe         6.690
# Uruguay       Latin America and Caribbean         6.431
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Australia                              0.041         7.265         7.102
# France                                 0.037         6.762         6.618
# Uruguay                                0.046         6.521         6.341
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Australia                    10.796           0.940                     73.9
# France                       10.704           0.942                     74.0
# Uruguay                       9.966           0.925                     69.1
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
wh.iloc[50:60]
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Latvia         Central and Eastern Europe         6.032
# Colombia      Latin America and Caribbean         6.012
# Hungary        Central and Eastern Europe         5.992
# Thailand                   Southeast Asia         5.985
# Nicaragua     Latin America and Caribbean         5.972
# Japan                           East Asia         5.940
# Argentina     Latin America and Caribbean         5.929
# Portugal                   Western Europe         5.929
# Honduras      Latin America and Caribbean         5.919
# Croatia        Central and Eastern Europe         5.882
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Latvia                                 0.036         6.103         5.961
# Colombia                               0.061         6.132         5.892
# Hungary                                0.047         6.085         5.899
# ...

# %% [markdown]
# ##### Vid 58

# %%
houses.loc[0:5, ['price', 'bedrooms']]
# Out:
#        price  bedrooms
# 0   221900.0         3
# 1   538000.0         3
# 2   180000.0         2
# 3   604000.0         4
# 4   510000.0         3
# 5  1225000.0         4

# %%
titanic.loc[50:60:2, ['name', 'sex', 'age']]
# Out:
#                                                  name     sex age
# 50  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58
# 52                            Carrau, Mr. Francisco M    male  28
# 54                Carter, Master. William Thornton II    male  11
# 56                         Carter, Mr. William Ernest    male  36
# 58                             Case, Mr. Howard Brown    male  49
# 60                      Cavendish, Mr. Tyrell William    male  36

# %%
wh.sort_index(inplace=True)

# %%
wh.loc['Canada': 'Denmark', ['Ladder score']]
# Out:
#                      Ladder score
# Country name
# Canada                      7.103
# Chad                        4.355
# Chile                       6.172
# China                       5.339
# Colombia                    6.012
# Comoros                     4.289
# Congo (Brazzaville)         5.342
# Costa Rica                  7.069
# Croatia                     5.882
# Cyprus                      6.223
# Czech Republic              6.965
# Denmark                     7.620
