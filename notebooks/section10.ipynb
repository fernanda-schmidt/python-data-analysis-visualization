# %% [markdown]
# ## Section 10
# ### Updating Values
# * 80: Renaming Columns and Index Labels
# * 81: The replace() method
# * 82: Updating Values Using loc[]
# * 83: Updating Multiple Values Using loc[]
# * 84: Making Updates with loc[] and Boolean Masks

# %%
import pandas as pd

# %%
houses = pd.read_csv('../datasets/data/kc_house_data.csv')
titanic = pd.read_csv('../datasets/data/titanic.csv')
netflix = pd.read_csv('../datasets/data/netflix_titles.csv', sep='|', index_col=0)
btc = pd.read_csv("../datasets/data/coin_Bitcoin.csv")
countries = pd.read_csv('../datasets/data/world-happiness-report-2021.csv')

# %%
countries.set_index('Country name', inplace=True)
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {'Regional indicator': 'regional_indicator', 'Ladder score': 'ladder_score'}
countries.rename(columns = mapper, inplace=True)

# %%
titanic.sex.replace('female', 'f')
# Out:
# 0          f
# 1       male
# 2          f
# 3       male
# 4          f
#         ...
# 1304       f
# 1305       f
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: str

# %%
titanic.sex.replace(['female', 'male'], ['F', 'M'])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: str

# %%
titanic.age.replace(['?'], [None], inplace=True).value_counts(dropna=False)
# Out:
# C:\Users\FERNANDA\AppData\Local\Temp\ipykernel_19752\259767482.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   titanic.age.replace(['?'], [None], inplace=True).value_counts(dropna=False)
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 60.5        1
# ...

# %%
countries.head()
# Out:
#              regional_indicator  ladder_score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], ['regional_indicator']]
# Out:
#              regional_indicator
# Country name
# Denmark          Western Europe
# Sweden           Western Europe
# Norway           Western Europe

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], ['regional_indicator']] = 'Scandinavia'
countries.head(10)
# Out:
#                  regional_indicator  ladder_score  \
# Country name
# Finland              Western Europe         7.842
# Denmark                 Scandinavia         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway                  Scandinavia         7.392
# Sweden                  Scandinavia         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway']]
# Out:
#              regional_indicator  ladder_score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark             Scandinavia         7.620                           0.035
# Iceland          Western Europe         7.554                           0.059
# Sweden              Scandinavia         7.363                           0.036
# Norway              Scandinavia         7.392                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Iceland              7.670         7.438                 10.878
# Sweden               7.433         7.293                 10.867
# Norway               7.462         7.323                 11.053
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway'], ['regional_indicator', 'isCold'] ] = ['Nordic Countries', 'Yes']

# %%
countries.head(10)
# Out:
#                  regional_indicator  ladder_score  \
# Country name
# Finland            Nordic Countries         7.842
# Denmark            Nordic Countries         7.620
# Switzerland          Western Europe         7.571
# Iceland            Nordic Countries         7.554
# Netherlands          Western Europe         7.464
# Norway             Nordic Countries         7.392
# Sweden             Nordic Countries         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...
