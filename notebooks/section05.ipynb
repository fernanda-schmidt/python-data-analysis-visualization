# %% [markdown]
# # Section 05
# ## Basic Dataframes Methods & Computations
# * Vid 31: Min & Max
# * Vid 32: Sum & Count
# * Vid 33: Mean, Median & Mode
# * Vid 34: Describe with Numeric Values
# * Vid 35: Describe with Objects (Text) Values

# %%
import pandas as pd
houses = pd.read_csv('../datasets/data/kc_house_data.csv')
houses.head()

# %% [markdown]
# ##### Vid 31

# %%
houses.min()

# %%
houses.max()

# %% [markdown]
# ##### Vid 32

# %%
houses.sum()

# %%
houses.sum(numeric_only=True)

# %%
titanic = pd.read_csv('../datasets/data/titanic.csv')
titanic.sum()

# %%
state_pop = pd.read_csv('../datasets/data/nst-est2020.csv')
state_pop.head()

# %%
state_pop.tail(52).head(51).sum(numeric_only=True)

# %%
titanic.count()

# %%
netflix = pd.read_csv('../datasets/data/netflix_titles.csv', sep='|', index_col=0)

netflix.count()

# %% [markdown]
# ##### Vid 33

# %%
houses.mean(numeric_only=True)

# %%
titanic.mean(numeric_only=True)

# %%
houses.median(numeric_only=True)

# %%
titanic.mode()

# %% [markdown]
# ##### Vid 34

# %%
titanic.describe()

# %%
houses.describe()

# %% [markdown]
# ##### Vid 35

# %%
titanic.describe(include=['object'])

# %%
houses.describe(include=['str'])

# %%
netflix.describe(include=['str'])
